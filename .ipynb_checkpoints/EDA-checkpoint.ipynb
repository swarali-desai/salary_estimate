# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('csv_files/salary_data_cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      Company Name Competitors  Founded Headquarters  \
# 0           0            Punchh          -1     2010           -1
# 1           1     Gensuite, LLC          -1     2008           -1
# 2           2       GroundTruth          -1     2009           -1
# 3           3  Amazon.com, Inc.          -1     1994           -1
# 4           4  Amazon.com, Inc.          -1     1994           -1
#
#                                   Industry  \
# 0  Enterprise Software & Network Solutions
# 1             Computer Hardware & Software
# 2                                       -1
# 3                                 Internet
# 4                                 Internet
#
#                                      Job Description               Job Title  \
# 0  Punchh creates the consistent, modern experien...            Data Analyst
# 1  Associate Data Analyst\n\nFull Time\nBangalore...  Associate Data Analyst
# 2  Role: Junior Data Analyst\n\nLocation: Gurgaon...     Junior Data Analyst
# 3  Amazon Indias Supply Chain & Analytics team is...    Data Analyst Support
# 4  Amazon's Marketplace Trust team works to ensur...            Data Analyst
#
#     Location  Rating  ... nltk power bi excel hadoop azure  scikit-learn  NLP  \
# 0     Jaipur     4.2  ...    0        1     0      0     0             0    0
# 1  Bengaluru     3.4  ...    0        0     1      0     0             0    0
# 2    Gurgaon     3.4  ...    0        0     1      0     0             0    0
# 3  Bengaluru     4.3  ...    0        0     1      0     0             0    0
# 4  Bengaluru     4.3  ...    0        0     1      0     0             0    0
#
#    r_prog  degree_req  job_simplifier
# 0       1           0    data analyst
# 1       1           0    data analyst
# 2       1           0    data analyst
# 3       0           0    data analyst
# 4       0           1    data analyst
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company Name', 'Competitors', 'Founded', 'Headquarters',
#        'Industry', 'Job Description', 'Job Title', 'Location', 'Rating',
#        'Revenue', 'Salary Estimate', 'Sector', 'Size', 'Type of ownership',
#        'avg_salary', 'min_salary', 'max_salary', 'age', 'python', 'sas', 'aws',
#        'spark', 'sql', 'tableau', 'tensorflow', 'nltk', 'power bi', 'excel',
#        'hadoop', 'azure', 'scikit-learn', 'NLP', 'r_prog', 'degree_req',
#        'job_simplifier'],
#       dtype='object')

# %%
#drop the first column
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'avg_salary',
#        'min_salary', 'max_salary', 'age', 'python', 'sas', 'aws', 'spark',
#        'sql', 'tableau', 'tensorflow', 'nltk', 'power bi', 'excel', 'hadoop',
#        'azure', 'scikit-learn', 'NLP', 'r_prog', 'degree_req',
#        'job_simplifier'],
#       dtype='object')

# %% [markdown]
# # Some feature engineering

# %%
#determine the seniority for the job
def seniority(job_title):
    if 'senior' in job_title.lower() or 'sr ' in job_title.lower() or 'lead' in job_title.lower() or 'principal' in job_title.lower() or 'sr. ' in job_title.lower():
        return 'senior'
    elif 'junior' in job_title.lower() or 'jr ' in job_title.lower() or 'jr. ' in job_title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df['seniority'].value_counts()
# Out:
# na        407
# senior     64
# junior      4
# Name: seniority, dtype: int64

# %%
# job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0       2606
# 1       3982
# 2       3696
# 3       3283
# 4       2105
# 5       2901
# 6       6233
# 7       3449
# 8       1431
# 9       4707
# 10      3629
# 11      2710
# 12      4718
# 13      2685
# 14      7923
# 15      4591
# 16      2383
# 17      2348
# 18      4766
# 19      3726
# 20      3656
# 21       945
# 22      1869
# 23      3496
# 24       796
# 25       448
# 26      1452
# 27      4962
# 28      3454
# 29       952
# 30      2687
# 31      3878
# 32      1172
# 33      3683
# 34      2918
# 35      2978
# 36      1110
# 37      1274
# 38       271
# 39      3331
# 40      3545
# 41      2301
# 42      3095
# 43      2297
# 44      1036
# 45      5857
# 46      1021
# 47      4376
# 48       669
# 49      1227
# 50      4187
# 51      1035
# 52      2729
# 53      2207
# 54      1057
# 55      1395
# 56      1150
# 57      3031
# 58      2963
# 59      3966
# 60       853
# 61      6101
# 62      4724
# 63      2981
# 64       227
# 65      2197
# 66      2118
# 67      2083
# 68      3807
# 69      1783
# 70       125
# 71       805
# 72      5486
# 73      2608
# 74      5332
# 75      4813
# 76      5264
# 77      1364
# 78      1967
# 79      1722
# 80      2992
# 81      4403
# 82      2773
# 83       877
# 84      3934
# 85      1453
# 86      3782
# 87      5354
# 88      1992
# 89      1698
# 90      4249
# 91       513
# 92      4087
# 93      4706
# 94      3374
# 95      2850
# 96      4647
# 97      1606
# 98      4089
# 99      3580
# 100     1096
# 101     5603
# 102     3541
# 103     2970
# 104     1132
# 105     1452
# 106     2659
# 107     2606
# 108     4456
# 109      407
# 110     4274
# 111     4495
# 112     3646
# 113     6002
# 114     2815
# 115     1364
# 116      796
# 117      641
# 118     4039
# 119     1376
# 120     1881
# 121     1668
# 122     2112
# 123     2225
# 124     1951
# 125     1100
# 126     1397
# 127     3544
# 128    13260
# 129     1205
# 130     3266
# 131      349
# 132     4766
# 133     1608
# 134     2088
# 135     2197
# 136     4432
# 137     2559
# 138     2033
# 139     2029
# 140     3319
# 141     1157
# 142     2003
# 143     3449
# 144     2106
# 145     2174
# 146     2105
# 147     3629
# 148     2360
# 149     3714
# 150     4680
# 151     3367
# 152     6600
# 153     3919
# 154     2383
# 155     2596
# 156     4591
# 157     1603
# 158     6463
# 159     3105
# 160     6322
# 161     2033
# 162     3069
# 163     1769
# 164     2118
# 165      952
# 166     1691
# 167     1150
# 168     2708
# 169     3776
# 170     3862
# 171      723
# 172     4962
# 173     4547
# 174     1973
# 175     3170
# 176     3730
# 177      815
# 178     2800
# 179     2601
# 180      796
# 181     2918
# 182     2990
# 183     1087
# 184     1383
# 185     1875
# 186     2910
# 187     1108
# 188     2276
# 189     1458
# 190     2009
# 191      271
# 192      556
# 193      947
# 194     8104
# 195     3583
# 196     1304
# 197     3920
# 198     1984
# 199     4441
# 200     4441
# 201     1984
# 202     4441
# 203     1432
# 204     4985
# 205     2116
# 206     4797
# 207     1602
# 208     5937
# 209     4912
# 210     5603
# 211     1627
# 212     2659
# 213     3541
# 214     2184
# 215     1132
# 216     1452
# 217     2405
# 218     1722
# 219     4699
# 220      248
# 221     2306
# 222     9159
# 223     1096
# 224     1960
# 225      522
# 226     1552
# 227      896
# 228     5782
# 229     4513
# 230     3493
# 231     3713
# 232     5459
# 233     3792
# 234     2052
# 235     3528
# 236     4936
# 237     3234
# 238      800
# 239     2691
# 240     1453
# 241      155
# 242     1504
# 243     4892
# 244     2945
# 245     1750
# 246     1412
# 247     2377
# 248     2955
# 249     3893
# 250     2984
# 251     3106
# 252     3643
# 253     2509
# 254     1624
# 255     3136
# 256     4503
# 257      619
# 258     2130
# 259     3544
# 260     3559
# 261      255
# 262     2563
# 263     6704
# 264     4647
# 265      927
# 266     1825
# 267     4057
# 268     4406
# 269     3138
# 270     1964
# 271     3458
# 272     5543
# 273     3541
# 274     1626
# 275     3125
# 276     2596
# 277     2933
# 278     5413
# 279     4251
# 280     2482
# 281     6482
# 282     1864
# 283     3703
# 284     5478
# 285     4567
# 286     6975
# 287     6322
# 288     2163
# 289     2604
# 290     2815
# 291     6490
# 292     2776
# 293     4680
# 294     3981
# 295     2767
# 296     1238
# 297     4445
# 298     2769
# 299     4105
# 300     2933
# 301     3377
# 302      548
# 303     6478
# 304     4804
# 305      929
# 306     1140
# 307     1210
# 308      359
# 309     3600
# 310     2725
# 311     3591
# 312     3583
# 313     4428
# 314      422
# 315     2144
# 316     5516
# 317     1672
# 318     1209
# 319     1359
# 320     1571
# 321     3328
# 322     3322
# 323     3609
# 324     3268
# 325     2619
# 326     3119
# 327     3188
# 328     6188
# 329     4380
# 330      806
# 331     4064
# 332      669
# 333      985
# 334     6358
# 335     1704
# 336     3871
# 337     2934
# 338     1889
# 339     4916
# 340     3919
# 341     3695
# 342     3545
# 343     1544
# 344     1995
# 345     3688
# 346     2924
# 347     4369
# 348     2785
# 349     4402
# 350     3896
# 351     5945
# 352     4210
# 353     3679
# 354     5063
# 355     2685
# 356     3021
# 357     3694
# 358     4620
# 359     1188
# 360      738
# 361     3380
# 362     2665
# 363     2724
# 364     2198
# 365     4390
# 366     3006
# 367     3918
# 368     3150
# 369     4792
# 370     4294
# 371     6669
# 372     1672
# 373     3860
# 374     1601
# 375     2146
# 376     1326
# 377     2498
# 378     2939
# 379     3095
# 380     2146
# 381     3707
# 382     1230
# 383     1620
# 384     3075
# 385     1687
# 386     5025
# 387     2448
# 388      469
# 389     4064
# 390      294
# 391     1424
# 392     1148
# 393     5086
# 394     2349
# 395     1239
# 396     2885
# 397      987
# 398     1735
# 399      357
# 400     4230
# 401     1029
# 402     1266
# 403      452
# 404     2912
# 405     4249
# 406     2108
# 407     4247
# 408     4473
# 409     4101
# 410     1225
# 411     4318
# 412     1391
# 413     1179
# 414     2520
# 415     5386
# 416     1636
# 417     3664
# 418     2652
# 419     2094
# 420     1799
# 421     2203
# 422     2205
# 423     3364
# 424     1391
# 425     3140
# 426     3252
# 427     2170
# 428     3835
# 429     5276
# 430     1885
# 431     1423
# 432     4279
# 433     2031
# 434     2107
# 435      674
# 436     2367
# 437     4901
# 438     1169
# 439     2879
# 440     3140
# 441     1935
# 442     1694
# 443     5278
# 444     7214
# 445     3079
# 446      962
# 447     2184
# 448     5006
# 449     7131
# 450     2184
# 451     9360
# 452     3464
# 453     1936
# 454     2282
# 455     5049
# 456     3308
# 457     2020
# 458     1841
# 459     3491
# 460     2376
# 461     3196
# 462     2075
# 463     2559
# 464     1566
# 465     3475
# 466     5449
# 467     1679
# 468     2369
# 469     4460
# 470     4577
# 471      805
# 472     2275
# 473     1268
# 474     1992
# Name: desc_len, dtype: int64

# %%
# competitors count
df['competitor_count'] = df['Competitors'].apply(lambda x : len(x.split(',')) if x != '-1' else 0)
df['competitor_count'].value_counts()
# Out:
# 0    436
# 3     32
# 2      4
# 1      3
# Name: competitor_count, dtype: int64

# %% [markdown]
# we need to fill in the max and min salary where it is not available. According to google minimum salary for a data scientist in India is 4lpa but as the job role we have are different we cannot directly assign 4lpa to every role. Out 475 rows 293 have no value for min and max salary.

# %%
print("min of max salary: ", min(df['max_salary']))
print("max of max salary: ", max(df['max_salary']))
print("min of min salary: ", min(df['min_salary']))
print("max of min salary: ", max(df['min_salary']))
# Out:
# min of max salary:  0
# max of max salary:  6531000
# min of min salary:  0
# max of min salary:  6025000

# %% [markdown]
# # Exploratory data analysis

# %%
df.describe()
# Out:
#           Founded      Rating    avg_salary    min_salary    max_salary  \
# count   475.00000  475.000000  4.750000e+02  4.750000e+02  4.750000e+02
# mean   1676.72000    3.765684  1.027949e+06  3.305326e+05  4.015074e+05
# std     717.33974    0.925210  6.948402e+05  6.600465e+05  7.782119e+05
# min      -1.00000   -1.000000  1.050000e+05  0.000000e+00  0.000000e+00
# 25%    1913.00000    3.500000  5.236865e+05  0.000000e+00  0.000000e+00
# 50%    1996.00000    3.900000  8.641470e+05  0.000000e+00  0.000000e+00
# 75%    2010.00000    4.200000  1.439361e+06  4.590000e+05  5.375000e+05
# max    2019.00000    5.000000  6.278000e+06  6.025000e+06  6.531000e+06
#
#               age      python         sas         aws       spark  ...  \
# count  475.000000  475.000000  475.000000  475.000000  475.000000  ...
# mean    32.530526    0.585263    0.082105    0.261053    0.273684  ...
# std     50.669282    0.493196    0.274814    0.439672    0.446319  ...
# min     -1.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%      5.000000    0.000000    0.000000    0.000000    0.000000  ...
# 50%     15.000000    1.000000    0.000000    0.000000    0.000000  ...
# 75%     28.500000    1.000000    0.000000    1.000000    1.000000  ...
# max    330.000000    1.000000    1.000000    1.000000    1.000000  ...
#
#          power bi       excel      hadoop       azure  scikit-learn    NLP  \
# count  475.000000  475.000000  475.000000  475.000000    475.000000  475.0
# mean     0.050526    0.469474    0.258947    0.101053      0.046316    0.0
# std      0.219259    0.499593    0.438518    0.301716      0.210390    0.0
# min      0.000000    0.000000    0.000000    0.000000      0.000000    0.0
# 25%      0.000000    0.000000    0.000000    0.000000      0.000000    0.0
# 50%      0.000000    0.000000    0.000000    0.000000      0.000000    0.0
# 75%      0.000000    1.000000    1.000000    0.000000      0.000000    0.0
# max      1.000000    1.000000    1.000000    1.000000      1.000000    0.0
#
#            r_prog  degree_req      desc_len  competitor_count
# count  475.000000  475.000000    475.000000        475.000000
# mean     0.218947    0.061053   2939.734737          0.225263
# std      0.413969    0.239679   1675.469016          0.772547
# min      0.000000    0.000000    125.000000          0.000000
# 25%      0.000000    0.000000   1672.000000          0.000000
# 50%      0.000000    0.000000   2769.000000          0.000000
# 75%      0.000000    0.000000   3919.000000          0.000000
# max      1.000000    1.000000  13260.000000          3.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Analyzing Continous Values

# %%
df_cont = df[['avg_salary', 'Rating', 'age','desc_len','competitor_count']]

# plotting histograms
fig, axs = plt.subplots(2, 2, figsize=(20, 10))
axs[0, 0].hist(df_cont['avg_salary'], bins=30, edgecolor='white', linewidth=1.2,color = "rebeccapurple")
axs[0, 0].set_title('Average Salary')
axs[0, 1].hist(df_cont['Rating'], bins=30, edgecolor='white', linewidth=1.2,color = "rebeccapurple")
axs[0, 1].set_title('Company Rating')
axs[1, 0].hist(df_cont['age'], bins=30, edgecolor='white', linewidth=1.2,color = "rebeccapurple")
axs[1, 0].set_title('Age of the company')
axs[1, 1].hist(df_cont['desc_len'], bins=30, edgecolor='white', linewidth=1.2,color = "rebeccapurple")
axs[1, 1].set_title('Job description length')
# Out:
# Text(0.5, 1.0, 'Job description length')

# %% [markdown]
# * Average salary is normally distributed with mean value of INR 10,27,949.48
# * Company rating is normally distributed with mean value of 3.7
# * Company age shows exponential distribution with mean value of 32. Mostly many companies are fairly new.
# * Job description length is also normally distributed with a mean value of 2939 characters.

# %%
# plot correlation heatmap
sns.heatmap(df_cont.corr(), annot=True)

# %% [markdown]
# * The age of the company and the Job description length shows some correlation. Probably the old and established companies must be having an elaborate job description.
# * The average salary is correlated with Company age, Job decription length and Competitor count.
# * Lastly the Company rating is somewhat correlated with the job decsription length, maybe companies with higher ratings post more elaborate job description.
# * It is interesting to see that the Average salary and rating is not highly correlated.

# %% [markdown]
# # Analyzing Categorical Values

# %%
sns.set(style="white")

# %%
df_cat = df[['Location','Industry','Sector','Headquarters','job_simplifier', 'python', 'sas', 'aws', 'spark',
       'sql', 'tableau', 'tensorflow', 'nltk', 'power bi', 'excel', 'hadoop',
       'azure', 'scikit-learn', 'NLP', 'r_prog', 'degree_req',
       'seniority' ]]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    if len(cat_num) > 8:
        plt.figure(figsize=(15,4))
    cmap = sns.cubehelix_palette(light=1, as_cmap=True)
    chart = sns.barplot(x=cat_num.index, y=cat_num, palette="plasma")
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 29
# graph for Industry: total = 41
# graph for Sector: total = 17
# graph for Headquarters: total = 53
# graph for job_simplifier: total = 12
# graph for python: total = 2
# graph for sas: total = 2
# graph for aws: total = 2
# graph for spark: total = 2
# graph for sql: total = 2
# graph for tableau: total = 2
# graph for tensorflow: total = 2
# graph for nltk: total = 2
# graph for power bi: total = 2
# graph for excel: total = 2
# graph for hadoop: total = 2
# graph for azure: total = 2
# graph for scikit-learn: total = 2
# graph for NLP: total = 1
# graph for r_prog: total = 2
# graph for degree_req: total = 2
# graph for seniority: total = 3

# %%
pd.pivot_table(df, index = 'job_simplifier', values = 'avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                      avg_salary
# job_simplifier
# data scientist     1.272900e+06
# data engineer      1.202376e+06
# manager            1.191135e+06
# na                 1.190953e+06
# BDE                1.138436e+06
# software engineer  1.043816e+06
# MLE                9.729689e+05
# NLPE               9.639389e+05
# BA                 9.403755e+05
# data analyst       7.350285e+05
# AIE                5.365833e+05
# DLE                4.444744e+05

# %%
pd.pivot_table(df, index = ['job_simplifier','seniority'], values = 'avg_salary')
# Out:
#                                avg_salary
# job_simplifier    seniority
# AIE               na         5.365833e+05
# BA                na         9.323690e+05
#                   senior     1.030448e+06
# BDE               na         1.018160e+06
#                   senior     1.634577e+06
# DLE               na         3.118960e+05
#                   senior     9.747880e+05
# MLE               na         9.713936e+05
#                   senior     1.056459e+06
# NLPE              na         6.311388e+05
#                   senior     1.407672e+06
# data analyst      junior     5.367500e+05
#                   na         7.360727e+05
#                   senior     8.847500e+05
# data engineer     na         1.178271e+06
#                   senior     1.353894e+06
# data scientist    na         1.187534e+06
#                   senior     1.823034e+06
# manager           na         1.191135e+06
# na                junior     9.896660e+05
#                   na         1.178904e+06
#                   senior     1.253013e+06
# software engineer na         9.988598e+05
#                   senior     1.088773e+06

# %%
pd.pivot_table(df, index = ['Location','job_simplifier'], values = 'avg_salary').sort_values('Location')
# Out:
#                                          avg_salary
# Location            job_simplifier
# Ahmedabad           BA                 8.000000e+05
#                     MLE                6.445000e+05
#                     data analyst       5.412770e+05
# Andheri             data scientist     2.400000e+05
# Andhra Pradesh      data scientist     1.421000e+06
# Bagalur             MLE                8.349240e+05
# Bengaluru           software engineer  8.377121e+05
#                     na                 1.424630e+06
#                     manager            1.040146e+06
#                     data scientist     1.269547e+06
#                     data engineer      1.236450e+06
#                     data analyst       8.505588e+05
#                     MLE                1.093837e+06
#                     DLE                5.755840e+05
#                     BDE                1.261342e+06
#                     BA                 1.152680e+06
#                     AIE                3.900000e+05
#                     NLPE               7.497290e+05
# Bhubaneswar         BA                 7.608080e+05
# Chandigarh          AIE                5.000000e+05
#                     BA                 8.773090e+05
# Chennai             data analyst       4.601600e+05
#                     software engineer  4.732465e+05
#                     na                 1.159927e+06
#                     data engineer      8.277500e+05
#                     NLPE               6.373940e+05
#                     data scientist     1.948841e+06
#                     DLE                9.747880e+05
#                     BDE                1.057024e+06
#                     MLE                7.977812e+05
#                     BA                 5.278785e+05
#                     AIE                3.060000e+05
# Chhota Udaipur      na                 2.940000e+05
# Coimbatore          MLE                8.349240e+05
# Ernakulam           na                 3.000000e+05
# Gurgaon             na                 1.016007e+06
#                     data scientist     1.380833e+06
#                     data engineer      1.637214e+06
#                     software engineer  1.784472e+06
#                     MLE                8.349240e+05
#                     BDE                5.771580e+05
#                     BA                 9.124753e+05
#                     data analyst       7.870414e+05
# Hiranandani Gardens data analyst       4.000000e+05
# Hyderabad           software engineer  1.454322e+06
#                     na                 1.688706e+06
#                     data scientist     1.318789e+06
#                     data engineer      9.960810e+05
#                     data analyst       9.927535e+05
#                     MLE                9.589167e+05
#                     DLE                2.310000e+05
#                     BDE                1.012053e+06
#                     BA                 8.863215e+05
#                     AIE                2.735000e+05
#                     NLPE               3.896310e+05
# India               data scientist     1.427500e+06
#                     software engineer  1.169500e+06
#                     na                 4.633642e+05
#                     data engineer      9.555000e+05
#                     BDE                9.245683e+05
#                     MLE                5.349620e+05
#                     data analyst       4.736115e+05
#                     DLE                2.100000e+05
# Indore              BA                 7.608080e+05
# Jaipur              BA                 6.600000e+05
#                     data analyst       3.870990e+05
#                     na                 2.940000e+05
# Kanpur Nagar        MLE                9.840000e+05
# Kharar              data analyst       3.655440e+05
# Kochi               software engineer  4.740000e+05
#                     BA                 7.314330e+05
#                     data analyst       1.860180e+05
#                     na                 6.000000e+05
# Kolkata             na                 5.340000e+05
#                     BA                 7.778710e+05
# Mumbai              BA                 1.133750e+06
#                     MLE                9.285653e+05
#                     NLPE               1.749250e+06
#                     data analyst       6.079385e+05
#                     data engineer      5.167850e+05
#                     data scientist     9.061017e+05
#                     manager            1.795088e+06
#                     na                 1.170882e+06
#                     software engineer  1.104484e+06
# New Delhi           data engineer      1.471205e+06
#                     data scientist     9.660000e+05
#                     MLE                4.350000e+05
#                     BDE                8.171137e+05
#                     data analyst       4.255000e+05
# Noida               BA                 7.778710e+05
#                     MLE                7.714795e+05
#                     data analyst       7.192094e+05
#                     data scientist     6.702110e+05
#                     na                 9.160590e+05
#                     software engineer  8.876370e+05
# Pune                software engineer  1.468131e+06
#                     na                 1.051226e+06
#                     data scientist     1.266418e+06
#                     data engineer      1.544280e+06
#                     NLPE               8.349240e+05
#                     MLE                1.098550e+06
#                     BDE                1.708991e+06
#                     BA                 1.226709e+06
#                     data analyst       8.896894e+05
# SAS Nagar           BA                 3.780000e+05
#                     data analyst       5.165000e+05
# Tamil Nadu          data analyst       1.088500e+06
# Thiruvananthapuram  MLE                9.000000e+05
#                     AIE                1.250000e+06
#                     BA                 4.540800e+05
# Vadodara            data analyst       4.140000e+05

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['Location','job_simplifier'], values = 'avg_salary', aggfunc = 'count').sort_values('Location', ascending = False)
# Out:
#                                        avg_salary
# Location            job_simplifier
# Vadodara            data analyst                1
# Thiruvananthapuram  MLE                         1
#                     BA                          1
#                     AIE                         1
# Tamil Nadu          data analyst                1
# SAS Nagar           data analyst                1
#                     BA                          1
# Pune                NLPE                        1
#                     BA                          7
#                     BDE                         2
#                     MLE                         5
#                     data analyst                5
#                     data engineer               6
#                     data scientist              9
#                     na                          3
#                     software engineer           4
# Noida               software engineer           1
#                     na                          1
#                     data scientist              2
#                     data analyst                5
#                     MLE                         2
#                     BA                          2
# New Delhi           data analyst                1
#                     MLE                         1
#                     BDE                         3
#                     data engineer               1
#                     data scientist              1
# Mumbai              software engineer           2
#                     na                          7
#                     manager                     1
#                     data scientist              6
#                     data engineer               2
#                     data analyst                8
#                     NLPE                        2
#                     MLE                         3
#                     BA                          2
# Kolkata             na                          1
#                     BA                          1
# Kochi               BA                          2
#                     data analyst                2
#                     na                          2
#                     software engineer           1
# Kharar              data analyst                1
# Kanpur Nagar        MLE                         2
# Jaipur              na                          1
#                     data analyst                5
#                     BA                          1
# Indore              BA                          1
# India               DLE                         1
#                     software engineer           1
#                     na                          4
#                     data scientist              1
#                     data engineer               1
#                     data analyst                2
#                     MLE                         2
#                     BDE                         3
# Hyderabad           na                          9
#                     data scientist              5
#                     data engineer               7
#                     data analyst               13
#                     NLPE                        1
#                     MLE                         6
#                     DLE                         2
#                     BDE                         4
#                     BA                          6
#                     AIE                         1
#                     software engineer           3
# Hiranandani Gardens data analyst                1
# Gurgaon             data analyst               11
#                     BA                          6
#                     BDE                         2
#                     MLE                         1
#                     na                          8
#                     data engineer               1
#                     data scientist              3
#                     software engineer           2
# Ernakulam           na                          1
# Coimbatore          MLE                         1
# Chhota Udaipur      na                          1
# Chennai             BA                          4
#                     BDE                         6
#                     data engineer               2
#                     AIE                         1
#                     MLE                         4
#                     DLE                         1
#                     data scientist              6
#                     NLPE                        2
#                     na                          6
#                     software engineer           4
#                     data analyst                7
# Chandigarh          BA                          1
#                     AIE                         2
# Bhubaneswar         BA                          1
# Bengaluru           NLPE                        1
#                     AIE                         1
#                     BA                         12
#                     BDE                        21
#                     DLE                         1
#                     MLE                        24
#                     data scientist             32
#                     data analyst               30
#                     data engineer              31
#                     manager                     4
#                     na                         23
#                     software engineer           8
# Bagalur             MLE                         1
# Andhra Pradesh      data scientist              1
# Andheri             data scientist              1
# Ahmedabad           data analyst                3
#                     MLE                         1
#                     BA                          1

# %%
pd.pivot_table(df[df.job_simplifier == 'data scientist'], index = 'Location', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                   avg_salary
# Location
# Chennai         1.948841e+06
# India           1.427500e+06
# Andhra Pradesh  1.421000e+06
# Gurgaon         1.380833e+06
# Hyderabad       1.318789e+06
# Bengaluru       1.269547e+06
# Pune            1.266418e+06
# New Delhi       9.660000e+05
# Mumbai          9.061017e+05
# Noida           6.702110e+05
# Andheri         2.400000e+05

# %%
df.columns
# Out:
# Index(['Company Name', 'Competitors', 'Founded', 'Headquarters', 'Industry',
#        'Job Description', 'Job Title', 'Location', 'Rating', 'Revenue',
#        'Salary Estimate', 'Sector', 'Size', 'Type of ownership', 'avg_salary',
#        'min_salary', 'max_salary', 'age', 'python', 'sas', 'aws', 'spark',
#        'sql', 'tableau', 'tensorflow', 'nltk', 'power bi', 'excel', 'hadoop',
#        'azure', 'scikit-learn', 'NLP', 'r_prog', 'degree_req',
#        'job_simplifier', 'seniority', 'desc_len', 'competitor_count'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'competitor_count','python', 'sas', 'aws', 'spark',
       'sql', 'tableau', 'tensorflow', 'nltk', 'power bi', 'excel', 'hadoop',
       'azure', 'scikit-learn', 'NLP', 'r_prog', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns[:-1]:
    print('_____________________')
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#           avg_salary
# Rating
#  2.7    1.500000e+06
#  4.3    1.480159e+06
#  1.8    1.394398e+06
#  4.1    1.304603e+06
#  3.0    1.271117e+06
#  3.9    1.248251e+06
#  4.5    1.159890e+06
#  3.5    1.068239e+06
#  2.8    1.040220e+06
#  4.0    1.024014e+06
#  3.8    1.020647e+06
#  4.2    1.011578e+06
#  3.7    9.362921e+05
# -1.0    9.142841e+05
#  3.4    9.008458e+05
#  2.9    8.717386e+05
#  3.1    8.610228e+05
#  4.4    8.527209e+05
#  3.6    8.385965e+05
#  4.8    7.519063e+05
#  4.9    7.094978e+05
#  3.3    6.968749e+05
#  4.7    6.955473e+05
#  3.2    6.927355e+05
#  5.0    6.860733e+05
#  2.5    6.514155e+05
#  2.3    5.340000e+05
#  4.6    3.838480e+05
#  2.6    3.770400e+05
# Industry
#                                            avg_salary
# Industry
# Oil & Gas Exploration & Production       4.318500e+06
# TV Broadcast & Cable Networks            3.084051e+06
# Lending                                  2.908706e+06
# Cable, Internet & Telephone Providers    1.946500e+06
# Banks & Credit Unions                    1.739541e+06
# Music Production & Distribution          1.683596e+06
# Telecommunications Services              1.591222e+06
# Colleges & Universities                  1.502515e+06
# TV Broadcasting & Cable Networks         1.500000e+06
# Banks & Building Societies               1.453000e+06
# Farm Support Services                    1.353906e+06
# Aerospace & Defence                      1.340000e+06
# Internet                                 1.321891e+06
# Architectural & Engineering Services     1.282436e+06
# Investment Banking & Asset Management    1.241784e+06
# Computer Hardware & Software             1.196051e+06
# Real Estate                              1.166806e+06
# Energy                                   1.164500e+06
# Enterprise Software & Network Solutions  1.072389e+06
# Advertising & Marketing                  1.051667e+06
# Consulting                               1.031232e+06
# Food Production                          9.555000e+05
# Healthcare Services & Hospitals          8.934205e+05
# Biotech & Pharmaceuticals                8.644425e+05
# Industrial Manufacturing                 8.470000e+05
# Health Care Services & Hospitals         8.167670e+05
# General Merchandise & Superstores        7.895000e+05
# IT Services                              7.821454e+05
# -1                                       7.754168e+05
# Insurance Carriers                       6.852693e+05
# Department, Clothing, & Shoe Stores      6.850000e+05
# K-12 Education                           6.525607e+05
# Chemical Manufacturing                   6.390000e+05
# Financial Analytics & Research           5.819213e+05
# Brokerage Services                       5.625245e+05
# Financial Transaction Processing         5.589540e+05
# Consumer Products Manufacturing          4.475990e+05
# Research & Development                   4.289155e+05
# Video Games                              3.733175e+05
# Staffing & Outsourcing                   3.620817e+05
# Electrical & Electronic Manufacturing    3.024220e+05
# Sector
#                                 avg_salary
# Sector
# Oil, Gas, Energy & Utilities  2.741500e+06
# Telecommunications            1.641976e+06
# Aerospace & Defence           1.340000e+06
# Finance                       1.211570e+06
# Media                         1.180564e+06
# Real Estate                   1.166806e+06
# Agriculture & Forestry        1.154703e+06
# Education                     1.077538e+06
# Information Technology        1.075679e+06
# Healthcare                    8.934205e+05
# Biotech & Pharmaceuticals     8.644425e+05
# Business Services             8.523926e+05
# Health Care                   8.167670e+05
# -1                            7.754168e+05
# Retail                        7.372500e+05
# Insurance                     6.852693e+05
# Manufacturing                 5.884367e+05
# Revenue
#                                     avg_salary
# Revenue
# ₹5 to ₹10 billion (INR)           1.785000e+06
# ₹500+ billion (INR)               1.480342e+06
# $5 to $10 billion (USD)           1.431978e+06
# ₹500 million to ₹1 billion (INR)  1.357000e+06
# ₹100 to ₹500 billion (INR)        1.352100e+06
# $2 to $5 billion (USD)            1.342552e+06
# $10+ billion (USD)                1.223546e+06
# $500 million to $1 billion (USD)  1.049302e+06
# ₹10 to ₹50 billion (INR)          1.026248e+06
# Unknown / Non-Applicable          9.606860e+05
# ₹1 to ₹5 billion (INR)            8.528364e+05
# ₹50 to ₹100 billion (INR)         8.520000e+05
# $25 to $50 million (USD)          8.476823e+05
# $1 to $5 million (USD)            8.259705e+05
# $1 to $2 billion (USD)            7.523909e+05
# $5 to $10 million (USD)           7.456308e+05
# Less than $1 million (USD)        7.435498e+05
# $100 to $500 million (USD)        6.877710e+05
# $10 to $25 million (USD)          6.781835e+05
# $50 to $100 million (USD)         6.165916e+05
# ₹100 to ₹500 million (INR)        5.100000e+05
# ₹10 to ₹50 million (INR)          1.957260e+05
# competitor_count
#                     avg_salary
# competitor_count
# 3                 1.562570e+06
# 2                 1.349734e+06
# 0                 9.878668e+05
# 1                 7.216407e+05
# python
#           avg_salary
# python
# 1       1.038856e+06
# 0       1.012559e+06
# sas
#        avg_salary
# sas
# 0    1.029063e+06
# 1    1.015502e+06
# aws
#        avg_salary
# aws
# 1    1.110708e+06
# 0    9.987128e+05
# spark
#          avg_salary
# spark
# 1      1.131192e+06
# 0      9.890463e+05
# sql
#        avg_salary
# sql
# 0    1.029705e+06
# 1    1.026329e+06
# tableau
#            avg_salary
# tableau
# 1        1.132825e+06
# 0        1.010126e+06
# tensorflow
#               avg_salary
# tensorflow
# 0           1.029446e+06
# 1           1.018679e+06
# nltk
#         avg_salary
# nltk
# 0     1.037112e+06
# 1     7.651038e+05
# power bi
#             avg_salary
# power bi
# 1         1.059938e+06
# 0         1.026247e+06
# excel
#          avg_salary
# excel
# 0      1.043543e+06
# 1      1.010328e+06
# hadoop
#           avg_salary
# hadoop
# 1       1.159439e+06
# 0       9.820030e+05
# azure
#          avg_salary
# azure
# 0      1.043651e+06
# 1      8.882688e+05
# scikit-learn
#                 avg_salary
# scikit-learn
# 1             1.385251e+06
# 0             1.010597e+06
# NLP
#        avg_salary
# NLP
# 0    1.027949e+06
# r_prog
#           avg_salary
# r_prog
# 1       1.142395e+06
# 0       9.958677e+05
# Type of ownership
#                                   avg_salary
# Type of ownership
# Company - Public                1.229403e+06
# Unknown                         1.017124e+06
# Subsidiary or Business Segment  9.438214e+05
# Company - Private               9.045348e+05
# Private Practice / Firm         8.060000e+05
# College / University            6.002340e+05
# Self-employed                   5.251947e+05

# %%
# lets see what other job titles are there apart from the simplified categories
plt.figure(figsize=(20,4))
chart = sns.countplot(df['Job Title'][df['job_simplifier'] == 'na'], palette="plasma")
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'CIB - Data Management - Operations Analyst'),
#  Text(0, 0, 'Junior Risk Analyst - Data Quality'),
#  Text(0, 0, 'Data Help Analyst, Adv'),
#  Text(0, 0, 'Data Research Analyst Marketing - Kolkata, India'),
#  Text(0, 0, 'Data Transformation Analyst'),
#  Text(0, 0, 'Developer Technology Engineer - AI'),
#  Text(0, 0, 'Associate Staff Engineer (Mobile-Hybrid)'),
#  Text(0, 0, 'Staff Engineer (Bigdata Admin)'),
#  Text(0, 0, 'Technical Services Engineer - Realm'),
#  Text(0, 0, 'Software Principal Engineer Java Full Stack'),
#  Text(0, 0, 'Network Operations Engineer'),
#  Text(0, 0, 'Software Principal Engineer'),
#  Text(0, 0, 'Analytics Consultant'),
#  Text(0, 0, 'Applied Scientist'),
#  Text(0, 0, 'Applied Scientist II'),
#  Text(0, 0, 'Data Science'),
#  Text(0, 0, 'Senior Data & Applied Scientist'),
#  Text(0, 0, 'Research scientist'),
#  Text(0, 0, 'Research Scientist'),
#  Text(0, 0, 'Junior Research Scientist'),
#  Text(0, 0, 'Sr. Research Scientist'),
#  Text(0, 0, 'Solutions Expert/Engineer'),
#  Text(0, 0, 'Engineer - Field Service'),
#  Text(0, 0, 'Senior Build & Release Engineer (Bangalore)'),
#  Text(0, 0, 'Cloud Engineer'),
#  Text(0, 0, 'Infrastructure Engineer'),
#  Text(0, 0, 'Sr. CRM Business Systems Analyst'),
#  Text(0, 0, 'Senior Consultant, Gurgaon, India'),
#  Text(0, 0, 'Billing System Analyst'),
#  Text(0, 0, 'Consultant - Business Process Analyst 1'),
#  Text(0, 0, 'Business Systems Analyst I'),
#  Text(0, 0, 'Market Risk Analyst'),
#  Text(0, 0, 'Governance - Analyst - Sr Analyst'),
#  Text(0, 0, 'Technical Analyst II'),
#  Text(0, 0, 'Business Analysis - Associate'),
#  Text(0, 0, 'Credit Analyst'),
#  Text(0, 0, 'Business Systems Analyst'),
#  Text(0, 0, 'Technical & Business Operations Analyst'),
#  Text(0, 0, 'Business Research Analyst I'),
#  Text(0, 0, 'MTS 1, Business Systems Analyst'),
#  Text(0, 0, 'Associate Sales Engineer Analyst'),
#  Text(0, 0, 'Technology Business Finance Analyst I'),
#  Text(0, 0, 'Product Engineering Expert - AI/NLP'),
#  Text(0, 0, 'Principal Engineer (Full Stack)'),
#  Text(0, 0, 'Software Development Engineer'),
#  Text(0, 0, 'Verification Engineer - Low Power'),
#  Text(0, 0, 'Business Intelligence Engineer'),
#  Text(0, 0, 'SOTWARE ENGINEER (AI / NLP)'),
#  Text(0, 0, 'Senior Consultant - Information Engineer'),
#  Text(0, 0, 'Lymbyc-NLP/ AI Analyst'),
#  Text(0, 0, 'Backend Engineer - Senior'),
#  Text(0, 0, 'Senior Consultant - Graph Back End Engineer'),
#  Text(0, 0, 'Staff Research Engineer, End User Computing CTO Office Advanced Development'),
#  Text(0, 0, 'Verification Engineer - Hardware'),
#  Text(0, 0, 'Lead Consultant - Information Engineer'),
#  Text(0, 0, 'ES Tech, Business Intelligence Engineer'),
#  Text(0, 0, 'Conversation Bot Engineer'),
#  Text(0, 0, 'Sr. Verification Engineer'),
#  Text(0, 0, 'Test Automation Engineer - 280720'),
#  Text(0, 0, 'CIEL/SEL/14105: Senior Analytics Engineer'),
#  Text(0, 0, 'Verification Engineer'),
#  Text(0, 0, 'Development / Research Engineer'),
#  Text(0, 0, 'DevOps Engineer - 170320'),
#  Text(0, 0, 'Python Engineer'),
#  Text(0, 0, 'SMTS Verification Engineer'),
#  Text(0, 0, 'Apps Systems Engineer 5'),
#  Text(0, 0, 'Sr. Verification Design Engineer')]

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import random
# nltk.download('stopwords')
# nltk.download('punkt')

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =1500, height = 800,colormap="RdPu")
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

wc.to_file('eda_word_cloud.png')
